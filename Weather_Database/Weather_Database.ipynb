# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
from keychain import weather_key

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=2000)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=2000)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 784

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | starokostyantyniv
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | adrar
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | saint-augustin
# Processing Record 9 of Set 1 | mount isa
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | coahuayana
# Processing Record 12 of Set 1 | port elizabeth
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | oistins
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | hun
# Processing Record 17 of Set 1 | yulara
# Processing Record 18 of Set 1 | izumo
# Processing Record 19 of Set 1 | bay roberts
# Processing Record 20 of Set 1 | qaqortoq
# Processing Record 21 of Set 1 | cap malheureux
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | corn island
# Processing Record 24 of Set 1 | dingle
# Processing Record 25 of Set 1 | mayo
# Processing Record 26 of Set 1 | saint-louis
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | lagoa
# Processing Record 33 of Set 1 | isangel
# Processing Record 34 of Set 1 | itarema
# Processing Record 35 of Set 1 | tuatapere
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | mragowo
# Processing Record 38 of Set 1 | katsuura
# Processing Record 39 of Set 1 | kodiak
# Processing Record 40 of Set 1 | san francisco
# Processing Record 41 of Set 1 | diffa
# Processing Record 42 of Set 1 | tadine
# Processing Record 43 of Set 1 | provideniya
# Processing Record 44 of Set 1 | noumea
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | lompoc
# Processing Record 47 of Set 1 | rawson
# Processing Record 48 of Set 1 | ribeira grande
# Processing Record 49 of Set 1 | turkan
# Processing Record 50 of Set 1 | robe
# Processing Record 1 of Set 2 | tecoanapa
# Processing Record 2 of Set 2 | cayenne
# Processing Record 3 of Set 2 | kavaratti
# Processing Record 4 of Set 2 | tura
# Processing Record 5 of Set 2 | totness
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | plettenberg bay
# Processing Record 8 of Set 2 | castro
# Processing Record 9 of Set 2 | east london
# Processing Record 10 of Set 2 | beidao
# Processing Record 11 of Set 2 | papara
# Processing Record 12 of Set 2 | shintomi
# Processing Record 13 of Set 2 | kalmar
# Processing Record 14 of Set 2 | beyneu
# Processing Record 15 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 2 | alofi
# Processing Record 17 of Set 2 | addi ugri
# City not found. Skipping...
# Processing Record 18 of Set 2 | hofn
# Processing Record 19 of Set 2 | pisco
# Processing Record 20 of Set 2 | skibbereen
# Processing Record 21 of Set 2 | sao filipe
# Processing Record 22 of Set 2 | samarai
# Processing Record 23 of Set 2 | dubbo
# Processing Record 24 of Set 2 | tumaco
# Processing Record 25 of Set 2 | kapaa
# Processing Record 26 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 2 | urumqi
# Processing Record 28 of Set 2 | copiapo
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | saint-philippe
# Processing Record 31 of Set 2 | thinadhoo
# Processing Record 32 of Set 2 | mataura
# Processing Record 33 of Set 2 | faanui
# Processing Record 34 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 2 | thompson
# Processing Record 36 of Set 2 | omsukchan
# Processing Record 37 of Set 2 | namibe
# Processing Record 38 of Set 2 | husavik
# Processing Record 39 of Set 2 | yurla
# Processing Record 40 of Set 2 | bredasdorp
# Processing Record 41 of Set 2 | tasiilaq
# Processing Record 42 of Set 2 | pavlohrad
# Processing Record 43 of Set 2 | salalah
# Processing Record 44 of Set 2 | cherskiy
# Processing Record 45 of Set 2 | xai-xai
# Processing Record 46 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 2 | mandalgovi
# Processing Record 48 of Set 2 | abha
# Processing Record 49 of Set 2 | catuday
# Processing Record 50 of Set 2 | airai
# Processing Record 1 of Set 3 | kaitangata
# Processing Record 2 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 3 | progreso
# Processing Record 4 of Set 3 | hilo
# Processing Record 5 of Set 3 | longyearbyen
# Processing Record 6 of Set 3 | cape town
# Processing Record 7 of Set 3 | ladario
# Processing Record 8 of Set 3 | hay river
# Processing Record 9 of Set 3 | pangnirtung
# Processing Record 10 of Set 3 | arlit
# Processing Record 11 of Set 3 | avanigadda
# Processing Record 12 of Set 3 | ancud
# Processing Record 13 of Set 3 | matara
# Processing Record 14 of Set 3 | vandra
# Processing Record 15 of Set 3 | namatanai
# Processing Record 16 of Set 3 | khatanga
# Processing Record 17 of Set 3 | eirunepe
# Processing Record 18 of Set 3 | lucapa
# Processing Record 19 of Set 3 | balkhash
# Processing Record 20 of Set 3 | vao
# Processing Record 21 of Set 3 | mar del plata
# Processing Record 22 of Set 3 | tabou
# Processing Record 23 of Set 3 | georgetown
# Processing Record 24 of Set 3 | asau
# Processing Record 25 of Set 3 | voh
# Processing Record 26 of Set 3 | klaksvik
# Processing Record 27 of Set 3 | barrow
# Processing Record 28 of Set 3 | tuktoyaktuk
# Processing Record 29 of Set 3 | hamilton
# Processing Record 30 of Set 3 | bowen
# Processing Record 31 of Set 3 | bandarbeyla
# Processing Record 32 of Set 3 | leshukonskoye
# Processing Record 33 of Set 3 | grindavik
# Processing Record 34 of Set 3 | victor harbor
# Processing Record 35 of Set 3 | constitucion
# Processing Record 36 of Set 3 | whitehorse
# Processing Record 37 of Set 3 | solnechnyy
# Processing Record 38 of Set 3 | galle
# Processing Record 39 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 3 | bilma
# Processing Record 41 of Set 3 | hobart
# Processing Record 42 of Set 3 | deer lake
# Processing Record 43 of Set 3 | buka
# Processing Record 44 of Set 3 | arraial do cabo
# Processing Record 45 of Set 3 | dikson
# Processing Record 46 of Set 3 | west plains
# Processing Record 47 of Set 3 | ximei
# Processing Record 48 of Set 3 | te anau
# Processing Record 49 of Set 3 | aykhal
# Processing Record 50 of Set 3 | lichuan
# Processing Record 1 of Set 4 | san patricio
# Processing Record 2 of Set 4 | sinnamary
# Processing Record 3 of Set 4 | berlevag
# Processing Record 4 of Set 4 | jamestown
# Processing Record 5 of Set 4 | nipawin
# Processing Record 6 of Set 4 | houston
# Processing Record 7 of Set 4 | de-kastri
# Processing Record 8 of Set 4 | iqaluit
# Processing Record 9 of Set 4 | samarinda
# Processing Record 10 of Set 4 | puerto carreno
# Processing Record 11 of Set 4 | zhangye
# Processing Record 12 of Set 4 | aklavik
# Processing Record 13 of Set 4 | bethel
# Processing Record 14 of Set 4 | torbay
# Processing Record 15 of Set 4 | fritzlar
# Processing Record 16 of Set 4 | tiksi
# Processing Record 17 of Set 4 | grand gaube
# Processing Record 18 of Set 4 | vila do maio
# Processing Record 19 of Set 4 | trinidad
# Processing Record 20 of Set 4 | port hawkesbury
# Processing Record 21 of Set 4 | bodrum
# Processing Record 22 of Set 4 | sur
# Processing Record 23 of Set 4 | luganville
# Processing Record 24 of Set 4 | port hardy
# Processing Record 25 of Set 4 | atyrau
# Processing Record 26 of Set 4 | olinda
# Processing Record 27 of Set 4 | coihaique
# Processing Record 28 of Set 4 | havelock
# Processing Record 29 of Set 4 | loreto
# Processing Record 30 of Set 4 | port-gentil
# Processing Record 31 of Set 4 | mount gambier
# Processing Record 32 of Set 4 | magistralnyy
# Processing Record 33 of Set 4 | la maddalena
# Processing Record 34 of Set 4 | pinega
# Processing Record 35 of Set 4 | catu
# Processing Record 36 of Set 4 | bertoua
# Processing Record 37 of Set 4 | lazaro cardenas
# Processing Record 38 of Set 4 | ahome
# Processing Record 39 of Set 4 | soanierana ivongo
# Processing Record 40 of Set 4 | babayurt
# Processing Record 41 of Set 4 | temir
# Processing Record 42 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 43 of Set 4 | fare
# Processing Record 44 of Set 4 | chulman
# Processing Record 45 of Set 4 | usinsk
# Processing Record 46 of Set 4 | vostok
# Processing Record 47 of Set 4 | saint george
# Processing Record 48 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 4 | yar-sale
# Processing Record 50 of Set 4 | mehamn
# Processing Record 1 of Set 5 | palana
# Processing Record 2 of Set 5 | port hedland
# Processing Record 3 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 4 of Set 5 | kloulklubed
# Processing Record 5 of Set 5 | san angelo
# Processing Record 6 of Set 5 | birin
# Processing Record 7 of Set 5 | porto empedocle
# Processing Record 8 of Set 5 | zalantun
# Processing Record 9 of Set 5 | ligayan
# Processing Record 10 of Set 5 | norman wells
# Processing Record 11 of Set 5 | the valley
# Processing Record 12 of Set 5 | aksarka
# Processing Record 13 of Set 5 | taoudenni
# Processing Record 14 of Set 5 | dalhousie
# Processing Record 15 of Set 5 | hasaki
# Processing Record 16 of Set 5 | vila franca do campo
# Processing Record 17 of Set 5 | port macquarie
# Processing Record 18 of Set 5 | ponta delgada
# Processing Record 19 of Set 5 | talavera
# Processing Record 20 of Set 5 | upernavik
# Processing Record 21 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 22 of Set 5 | parana
# Processing Record 23 of Set 5 | bandipur
# Processing Record 24 of Set 5 | bambous virieux
# Processing Record 25 of Set 5 | pyshchug
# Processing Record 26 of Set 5 | faya
# Processing Record 27 of Set 5 | olafsvik
# Processing Record 28 of Set 5 | ostersund
# Processing Record 29 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 5 | bulgan
# Processing Record 31 of Set 5 | birao
# Processing Record 32 of Set 5 | kerrville
# Processing Record 33 of Set 5 | leningradskiy
# Processing Record 34 of Set 5 | columbus
# Processing Record 35 of Set 5 | ponta do sol
# Processing Record 36 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 5 | bengkulu
# Processing Record 38 of Set 5 | severodvinsk
# Processing Record 39 of Set 5 | cabo san lucas
# Processing Record 40 of Set 5 | touros
# Processing Record 41 of Set 5 | doha
# Processing Record 42 of Set 5 | wladyslawowo
# Processing Record 43 of Set 5 | otane
# Processing Record 44 of Set 5 | outjo
# Processing Record 45 of Set 5 | choya
# Processing Record 46 of Set 5 | sorland
# Processing Record 47 of Set 5 | saldanha
# Processing Record 48 of Set 5 | byron bay
# Processing Record 49 of Set 5 | kopavogur
# Processing Record 50 of Set 5 | geraldton
# Processing Record 1 of Set 6 | duncan
# Processing Record 2 of Set 6 | kashi
# Processing Record 3 of Set 6 | requena
# Processing Record 4 of Set 6 | minas
# Processing Record 5 of Set 6 | zhezkazgan
# Processing Record 6 of Set 6 | fethiye
# Processing Record 7 of Set 6 | petrovsk-zabaykalskiy
# Processing Record 8 of Set 6 | ust-nera
# Processing Record 9 of Set 6 | felidhoo
# City not found. Skipping...
# Processing Record 10 of Set 6 | gazanjyk
# Processing Record 11 of Set 6 | port lincoln
# Processing Record 12 of Set 6 | alta floresta
# Processing Record 13 of Set 6 | clyde river
# Processing Record 14 of Set 6 | necochea
# Processing Record 15 of Set 6 | ilulissat
# Processing Record 16 of Set 6 | margate
# Processing Record 17 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 18 of Set 6 | san juan
# Processing Record 19 of Set 6 | narsaq
# Processing Record 20 of Set 6 | velur
# Processing Record 21 of Set 6 | saint marys
# Processing Record 22 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 6 | wajima
# Processing Record 24 of Set 6 | misratah
# Processing Record 25 of Set 6 | mandera
# Processing Record 26 of Set 6 | prince rupert
# Processing Record 27 of Set 6 | korla
# Processing Record 28 of Set 6 | srednekolymsk
# Processing Record 29 of Set 6 | guerrero negro
# Processing Record 30 of Set 6 | dunhua
# Processing Record 31 of Set 6 | luderitz
# Processing Record 32 of Set 6 | pingzhuang
# Processing Record 33 of Set 6 | lata
# Processing Record 34 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 6 | jibuti
# Processing Record 36 of Set 6 | esperance
# Processing Record 37 of Set 6 | paragominas
# Processing Record 38 of Set 6 | victoria
# Processing Record 39 of Set 6 | chuy
# Processing Record 40 of Set 6 | egvekinot
# Processing Record 41 of Set 6 | elbeuf
# Processing Record 42 of Set 6 | karpathos
# Processing Record 43 of Set 6 | dumas
# Processing Record 44 of Set 6 | bubaque
# Processing Record 45 of Set 6 | leh
# Processing Record 46 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 47 of Set 6 | chifeng
# Processing Record 48 of Set 6 | pevek
# Processing Record 49 of Set 6 | college
# Processing Record 50 of Set 6 | porto novo
# Processing Record 1 of Set 7 | jiazi
# Processing Record 2 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 3 of Set 7 | naze
# Processing Record 4 of Set 7 | bolshaya rechka
# Processing Record 5 of Set 7 | zaragoza
# Processing Record 6 of Set 7 | tshikapa
# Processing Record 7 of Set 7 | conceicao do araguaia
# Processing Record 8 of Set 7 | camacari
# Processing Record 9 of Set 7 | kondoa
# Processing Record 10 of Set 7 | paamiut
# Processing Record 11 of Set 7 | ilhabela
# Processing Record 12 of Set 7 | sandpoint
# Processing Record 13 of Set 7 | souillac
# Processing Record 14 of Set 7 | grand-santi
# Processing Record 15 of Set 7 | port victoria
# Processing Record 16 of Set 7 | andros town
# Processing Record 17 of Set 7 | chapais
# Processing Record 18 of Set 7 | graaff-reinet
# Processing Record 19 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 7 | oranjestad
# Processing Record 21 of Set 7 | lebu
# Processing Record 22 of Set 7 | wenling
# Processing Record 23 of Set 7 | banda aceh
# Processing Record 24 of Set 7 | dawson creek
# Processing Record 25 of Set 7 | bathsheba
# Processing Record 26 of Set 7 | carnarvon
# Processing Record 27 of Set 7 | yefira
# City not found. Skipping...
# Processing Record 28 of Set 7 | ranong
# Processing Record 29 of Set 7 | okhotsk
# Processing Record 30 of Set 7 | antofagasta
# Processing Record 31 of Set 7 | labuhan
# Processing Record 32 of Set 7 | changli
# Processing Record 33 of Set 7 | gat
# Processing Record 34 of Set 7 | nadym
# Processing Record 35 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 7 | rio gallegos
# Processing Record 37 of Set 7 | winslow
# Processing Record 38 of Set 7 | nikolskoye
# Processing Record 39 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 40 of Set 7 | shipunovo
# Processing Record 41 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 42 of Set 7 | chokurdakh
# Processing Record 43 of Set 7 | axim
# Processing Record 44 of Set 7 | honningsvag
# Processing Record 45 of Set 7 | khagaria
# Processing Record 46 of Set 7 | wairoa
# Processing Record 47 of Set 7 | ixtapa
# Processing Record 48 of Set 7 | anadyr
# Processing Record 49 of Set 7 | narwar
# Processing Record 50 of Set 7 | hailey
# Processing Record 1 of Set 8 | merauke
# Processing Record 2 of Set 8 | muisne
# Processing Record 3 of Set 8 | ketchikan
# Processing Record 4 of Set 8 | chaumont
# Processing Record 5 of Set 8 | asfi
# Processing Record 6 of Set 8 | adre
# Processing Record 7 of Set 8 | haines junction
# Processing Record 8 of Set 8 | miracema do tocantins
# Processing Record 9 of Set 8 | yumen
# Processing Record 10 of Set 8 | beringovskiy
# Processing Record 11 of Set 8 | mkushi
# Processing Record 12 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 8 | nanortalik
# Processing Record 14 of Set 8 | fereydun kenar
# Processing Record 15 of Set 8 | muzhi
# Processing Record 16 of Set 8 | camopi
# Processing Record 17 of Set 8 | tautira
# Processing Record 18 of Set 8 | narrabri
# Processing Record 19 of Set 8 | velikiy ustyug
# Processing Record 20 of Set 8 | slave lake
# Processing Record 21 of Set 8 | benicarlo
# Processing Record 22 of Set 8 | adamovka
# Processing Record 23 of Set 8 | vestmannaeyjar
# Processing Record 24 of Set 8 | gayny
# Processing Record 25 of Set 8 | sartana
# Processing Record 26 of Set 8 | nhulunbuy
# Processing Record 27 of Set 8 | artvin
# Processing Record 28 of Set 8 | oussouye
# Processing Record 29 of Set 8 | tongzi
# Processing Record 30 of Set 8 | sirjan
# Processing Record 31 of Set 8 | bonthe
# Processing Record 32 of Set 8 | dehloran
# Processing Record 33 of Set 8 | kruisfontein
# Processing Record 34 of Set 8 | ballarpur
# Processing Record 35 of Set 8 | acapulco
# Processing Record 36 of Set 8 | ilebo
# Processing Record 37 of Set 8 | mahon
# Processing Record 38 of Set 8 | benguela
# Processing Record 39 of Set 8 | lakes entrance
# Processing Record 40 of Set 8 | broome
# Processing Record 41 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 8 | mugur-aksy
# Processing Record 43 of Set 8 | ratnagiri
# Processing Record 44 of Set 8 | bhainsdehi
# Processing Record 45 of Set 8 | tabas
# Processing Record 46 of Set 8 | viedma
# Processing Record 47 of Set 8 | paita
# Processing Record 48 of Set 8 | aden
# Processing Record 49 of Set 8 | ahuimanu
# Processing Record 50 of Set 8 | montes altos
# Processing Record 1 of Set 9 | barao de melgaco
# Processing Record 2 of Set 9 | bela
# Processing Record 3 of Set 9 | south valley
# Processing Record 4 of Set 9 | magadan
# Processing Record 5 of Set 9 | natalio
# Processing Record 6 of Set 9 | peniche
# Processing Record 7 of Set 9 | kungurtug
# Processing Record 8 of Set 9 | buraydah
# Processing Record 9 of Set 9 | flinders
# Processing Record 10 of Set 9 | largo
# Processing Record 11 of Set 9 | ekhabi
# Processing Record 12 of Set 9 | lahij
# Processing Record 13 of Set 9 | luba
# Processing Record 14 of Set 9 | portobelo
# Processing Record 15 of Set 9 | havoysund
# Processing Record 16 of Set 9 | cascais
# Processing Record 17 of Set 9 | linden
# Processing Record 18 of Set 9 | estelle
# Processing Record 19 of Set 9 | severnoye
# Processing Record 20 of Set 9 | barguzin
# Processing Record 21 of Set 9 | tingrela
# City not found. Skipping...
# Processing Record 22 of Set 9 | temiscaming
# Processing Record 23 of Set 9 | porbandar
# Processing Record 24 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 9 | tagusao
# Processing Record 26 of Set 9 | gerash
# Processing Record 27 of Set 9 | simi valley
# Processing Record 28 of Set 9 | ha tinh
# Processing Record 29 of Set 9 | jahrom
# City not found. Skipping...
# Processing Record 30 of Set 9 | lusambo
# Processing Record 31 of Set 9 | isfara
# Processing Record 32 of Set 9 | maymyo
# Processing Record 33 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 9 | ahipara
# Processing Record 35 of Set 9 | qasigiannguit
# Processing Record 36 of Set 9 | karratha
# Processing Record 37 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 9 | gisborne
# Processing Record 39 of Set 9 | ulladulla
# Processing Record 40 of Set 9 | lavrentiya
# Processing Record 41 of Set 9 | sokoni
# Processing Record 42 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 9 | poum
# Processing Record 44 of Set 9 | mazatlan
# Processing Record 45 of Set 9 | bud
# Processing Record 46 of Set 9 | mpanda
# Processing Record 47 of Set 9 | marquette
# Processing Record 48 of Set 9 | zheleznodorozhnyy
# Processing Record 49 of Set 9 | zinder
# Processing Record 50 of Set 9 | yamada
# Processing Record 1 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 2 of Set 10 | amapa
# Processing Record 3 of Set 10 | bolkhov
# Processing Record 4 of Set 10 | carlisle
# Processing Record 5 of Set 10 | ipixuna
# Processing Record 6 of Set 10 | meadow lake
# Processing Record 7 of Set 10 | tolaga bay
# Processing Record 8 of Set 10 | port pirie
# Processing Record 9 of Set 10 | great falls
# Processing Record 10 of Set 10 | khani
# Processing Record 11 of Set 10 | hearst
# Processing Record 12 of Set 10 | burica
# City not found. Skipping...
# Processing Record 13 of Set 10 | severo-kurilsk
# Processing Record 14 of Set 10 | mitsamiouli
# Processing Record 15 of Set 10 | kharagpur
# Processing Record 16 of Set 10 | hokitika
# Processing Record 17 of Set 10 | nouadhibou
# Processing Record 18 of Set 10 | vila velha
# Processing Record 19 of Set 10 | le pradet
# Processing Record 20 of Set 10 | torata
# Processing Record 21 of Set 10 | ucar
# Processing Record 22 of Set 10 | baoro
# Processing Record 23 of Set 10 | contai
# Processing Record 24 of Set 10 | los llanos de aridane
# Processing Record 25 of Set 10 | avera
# Processing Record 26 of Set 10 | half moon bay
# Processing Record 27 of Set 10 | roald
# Processing Record 28 of Set 10 | puerto quijarro
# Processing Record 29 of Set 10 | miles city
# Processing Record 30 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 31 of Set 10 | gimli
# Processing Record 32 of Set 10 | naica
# Processing Record 33 of Set 10 | muniz freire
# Processing Record 34 of Set 10 | along
# Processing Record 35 of Set 10 | almaznyy
# Processing Record 36 of Set 10 | pasinler
# Processing Record 37 of Set 10 | cortes
# Processing Record 38 of Set 10 | krasnozerskoye
# Processing Record 39 of Set 10 | sept-iles
# Processing Record 40 of Set 10 | dunedin
# Processing Record 41 of Set 10 | aguimes
# Processing Record 42 of Set 10 | bago
# Processing Record 43 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 44 of Set 10 | ostrovnoy
# Processing Record 45 of Set 10 | juneau
# Processing Record 46 of Set 10 | san mateo del mar
# Processing Record 47 of Set 10 | oranjemund
# Processing Record 48 of Set 10 | kiboga
# Processing Record 49 of Set 10 | turukhansk
# Processing Record 50 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 1 of Set 11 | bouna
# Processing Record 2 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 4 of Set 11 | mbekenyera
# Processing Record 5 of Set 11 | malente
# Processing Record 6 of Set 11 | lumphat
# Processing Record 7 of Set 11 | aswan
# Processing Record 8 of Set 11 | hobyo
# Processing Record 9 of Set 11 | polazna
# Processing Record 10 of Set 11 | caravelas
# Processing Record 11 of Set 11 | kieta
# Processing Record 12 of Set 11 | ryotsu
# Processing Record 13 of Set 11 | aksu
# Processing Record 14 of Set 11 | kalmunai
# Processing Record 15 of Set 11 | nantucket
# Processing Record 16 of Set 11 | jalapa
# Processing Record 17 of Set 11 | kahului
# Processing Record 18 of Set 11 | abashiri
# Processing Record 19 of Set 11 | nome
# Processing Record 20 of Set 11 | areka
# Processing Record 21 of Set 11 | berdigestyakh
# Processing Record 22 of Set 11 | ogdensburg
# Processing Record 23 of Set 11 | brockville
# Processing Record 24 of Set 11 | nianzishan
# Processing Record 25 of Set 11 | kapoeta
# Processing Record 26 of Set 11 | lorengau
# Processing Record 27 of Set 11 | henties bay
# Processing Record 28 of Set 11 | quatre cocos
# Processing Record 29 of Set 11 | hambantota
# Processing Record 30 of Set 11 | basse
# Processing Record 31 of Set 11 | yazykovo
# Processing Record 32 of Set 11 | litovko
# Processing Record 33 of Set 11 | sitka
# Processing Record 34 of Set 11 | kuala kedah
# Processing Record 35 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 36 of Set 11 | perth
# Processing Record 37 of Set 11 | dwarka
# Processing Record 38 of Set 11 | gondar
# Processing Record 39 of Set 11 | virginia beach
# Processing Record 40 of Set 11 | deh rawud
# City not found. Skipping...
# Processing Record 41 of Set 11 | venezuela
# Processing Record 42 of Set 11 | belmonte
# Processing Record 43 of Set 11 | cuamba
# Processing Record 44 of Set 11 | pennagaram
# Processing Record 45 of Set 11 | bima
# Processing Record 46 of Set 11 | manaure
# Processing Record 47 of Set 11 | keuruu
# Processing Record 48 of Set 11 | solton
# Processing Record 49 of Set 11 | niteroi
# Processing Record 50 of Set 11 | penzance
# Processing Record 1 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 12 | kodinsk
# Processing Record 3 of Set 12 | saint anthony
# Processing Record 4 of Set 12 | mana
# Processing Record 5 of Set 12 | gafanha da encarnacao
# Processing Record 6 of Set 12 | cabinda
# Processing Record 7 of Set 12 | harper
# Processing Record 8 of Set 12 | vanavara
# Processing Record 9 of Set 12 | diveyevo
# Processing Record 10 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 11 of Set 12 | jiexiu
# Processing Record 12 of Set 12 | eureka
# Processing Record 13 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 12 | yinchuan
# Processing Record 15 of Set 12 | bonfim
# Processing Record 16 of Set 12 | talnakh
# Processing Record 17 of Set 12 | thunder bay
# Processing Record 18 of Set 12 | vagur
# Processing Record 19 of Set 12 | biloela
# Processing Record 20 of Set 12 | daru
# Processing Record 21 of Set 12 | haifa
# Processing Record 22 of Set 12 | tapiramuta
# Processing Record 23 of Set 12 | madras
# Processing Record 24 of Set 12 | sola
# Processing Record 25 of Set 12 | eydhafushi
# Processing Record 26 of Set 12 | puyo
# Processing Record 27 of Set 12 | fort nelson
# Processing Record 28 of Set 12 | hachinohe
# Processing Record 29 of Set 12 | coaldale
# Processing Record 30 of Set 12 | malibu
# Processing Record 31 of Set 12 | sfantu gheorghe
# Processing Record 32 of Set 12 | codrington
# Processing Record 33 of Set 12 | beloha
# Processing Record 34 of Set 12 | saint-pierre
# Processing Record 35 of Set 12 | sydney
# Processing Record 36 of Set 12 | ilam
# Processing Record 37 of Set 12 | charters towers
# Processing Record 38 of Set 12 | mangrol
# Processing Record 39 of Set 12 | mosquera
# Processing Record 40 of Set 12 | bahile
# Processing Record 41 of Set 12 | nyurba
# Processing Record 42 of Set 12 | mount pleasant
# Processing Record 43 of Set 12 | piacabucu
# Processing Record 44 of Set 12 | dinsor
# City not found. Skipping...
# Processing Record 45 of Set 12 | tiruvottiyur
# City not found. Skipping...
# Processing Record 46 of Set 12 | lunao
# Processing Record 47 of Set 12 | terrace bay
# Processing Record 48 of Set 12 | san cristobal
# Processing Record 49 of Set 12 | nuuk
# Processing Record 50 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 1 of Set 13 | taree
# Processing Record 2 of Set 13 | maniitsoq
# Processing Record 3 of Set 13 | ballina
# Processing Record 4 of Set 13 | peterhead
# Processing Record 5 of Set 13 | montepuez
# Processing Record 6 of Set 13 | launceston
# Processing Record 7 of Set 13 | hazaribag
# Processing Record 8 of Set 13 | palma gil
# Processing Record 9 of Set 13 | vieux-habitants
# Processing Record 10 of Set 13 | hirara
# Processing Record 11 of Set 13 | suntar
# Processing Record 12 of Set 13 | mahebourg
# Processing Record 13 of Set 13 | verkhnevilyuysk
# Processing Record 14 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 15 of Set 13 | ayagoz
# Processing Record 16 of Set 13 | bethanien
# Processing Record 17 of Set 13 | meulaboh
# Processing Record 18 of Set 13 | umba
# Processing Record 19 of Set 13 | ambovombe
# Processing Record 20 of Set 13 | makat
# Processing Record 21 of Set 13 | coquimbo
# Processing Record 22 of Set 13 | cranbrook
# Processing Record 23 of Set 13 | azul
# Processing Record 24 of Set 13 | beaverlodge
# Processing Record 25 of Set 13 | port blair
# Processing Record 26 of Set 13 | sao jose da coroa grande
# Processing Record 27 of Set 13 | moa
# Processing Record 28 of Set 13 | kuzino
# Processing Record 29 of Set 13 | asyut
# Processing Record 30 of Set 13 | raga
# Processing Record 31 of Set 13 | linxia
# Processing Record 32 of Set 13 | polyarnyy
# Processing Record 33 of Set 13 | moundou
# Processing Record 34 of Set 13 | keningau
# Processing Record 35 of Set 13 | calama
# Processing Record 36 of Set 13 | ingham
# Processing Record 37 of Set 13 | maningrida
# Processing Record 38 of Set 13 | tarpa
# Processing Record 39 of Set 13 | komsomolskiy
# Processing Record 40 of Set 13 | san carlos de bariloche
# Processing Record 41 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 42 of Set 13 | sabha
# Processing Record 43 of Set 13 | mabaruma
# Processing Record 44 of Set 13 | masterton
# Processing Record 45 of Set 13 | porto murtinho
# Processing Record 46 of Set 13 | tres barras
# Processing Record 47 of Set 13 | price
# Processing Record 48 of Set 13 | gao
# Processing Record 49 of Set 13 | quelimane
# Processing Record 50 of Set 13 | cabo rojo
# Processing Record 1 of Set 14 | petushki
# Processing Record 2 of Set 14 | casablanca
# Processing Record 3 of Set 14 | huilong
# Processing Record 4 of Set 14 | lamesa
# Processing Record 5 of Set 14 | foz
# Processing Record 6 of Set 14 | saskylakh
# Processing Record 7 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 14 | mattawa
# Processing Record 9 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 14 | camana
# Processing Record 11 of Set 14 | ruwi
# Processing Record 12 of Set 14 | buala
# Processing Record 13 of Set 14 | kitui
# Processing Record 14 of Set 14 | praia
# Processing Record 15 of Set 14 | suihua
# Processing Record 16 of Set 14 | tambopata
# Processing Record 17 of Set 14 | plaisance-du-touch
# Processing Record 18 of Set 14 | pacifica
# Processing Record 19 of Set 14 | ukiah
# Processing Record 20 of Set 14 | noyabrsk
# Processing Record 21 of Set 14 | sabalgarh
# Processing Record 22 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 23 of Set 14 | liverpool
# Processing Record 24 of Set 14 | strezhevoy
# Processing Record 25 of Set 14 | tutoia
# Processing Record 26 of Set 14 | bilibino
# Processing Record 27 of Set 14 | riberalta
# Processing Record 28 of Set 14 | gawler
# Processing Record 29 of Set 14 | bandundu
# Processing Record 30 of Set 14 | goderich
# Processing Record 31 of Set 14 | superior
# Processing Record 32 of Set 14 | zhuhai
# Processing Record 33 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 14 | nelidovo
# Processing Record 35 of Set 14 | samana
# Processing Record 36 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 37 of Set 14 | wau
# Processing Record 38 of Set 14 | batemans bay
# Processing Record 39 of Set 14 | tazovskiy
# Processing Record 40 of Set 14 | pangody
# Processing Record 41 of Set 14 | chumikan
# Processing Record 42 of Set 14 | siva
# Processing Record 43 of Set 14 | paracuru
# Processing Record 44 of Set 14 | vardo
# Processing Record 45 of Set 14 | baculin
# Processing Record 46 of Set 14 | kamaishi
# Processing Record 47 of Set 14 | boende
# Processing Record 48 of Set 14 | tefe
# Processing Record 49 of Set 14 | kavieng
# Processing Record 50 of Set 14 | bacolod
# Processing Record 1 of Set 15 | carbonia
# Processing Record 2 of Set 15 | abu dhabi
# Processing Record 3 of Set 15 | awjilah
# Processing Record 4 of Set 15 | mao
# Processing Record 5 of Set 15 | rybnaya sloboda
# Processing Record 6 of Set 15 | jamame
# Processing Record 7 of Set 15 | tilichiki
# Processing Record 8 of Set 15 | gander
# Processing Record 9 of Set 15 | nalut
# Processing Record 10 of Set 15 | morros
# Processing Record 11 of Set 15 | qeshm
# Processing Record 12 of Set 15 | rupert
# Processing Record 13 of Set 15 | okoneshnikovo
# Processing Record 14 of Set 15 | dauphin
# Processing Record 15 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 15 | pulandian
# Processing Record 17 of Set 15 | zeya
# Processing Record 18 of Set 15 | binga
# Processing Record 19 of Set 15 | nemuro
# Processing Record 20 of Set 15 | yanchukan
# City not found. Skipping...
# Processing Record 21 of Set 15 | wolgast
# Processing Record 22 of Set 15 | kimbe
# Processing Record 23 of Set 15 | norashen
# Processing Record 24 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 25 of Set 15 | san policarpo
# Processing Record 26 of Set 15 | inverell
# Processing Record 27 of Set 15 | teguldet
# Processing Record 28 of Set 15 | karnobat
# Processing Record 29 of Set 15 | hami
# Processing Record 30 of Set 15 | yabassi
# Processing Record 31 of Set 15 | saint-georges
# Processing Record 32 of Set 15 | behbahan
# Processing Record 33 of Set 15 | marawi
# Processing Record 34 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 15 | troitsko-pechorsk
# Processing Record 36 of Set 15 | pangkalanbuun
# Processing Record 37 of Set 15 | whyalla
# Processing Record 38 of Set 15 | hastings
# Processing Record 39 of Set 15 | glens falls
# Processing Record 40 of Set 15 | kytlym
# City not found. Skipping...
# Processing Record 41 of Set 15 | kenai
# Processing Record 42 of Set 15 | wewak
# Processing Record 43 of Set 15 | fairbanks
# Processing Record 44 of Set 15 | pasighat
# Processing Record 45 of Set 15 | wum
# Processing Record 46 of Set 15 | pavlovka
# Processing Record 47 of Set 15 | bend
# Processing Record 48 of Set 15 | havre-saint-pierre
# Processing Record 49 of Set 15 | new london
# Processing Record 50 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 1 of Set 16 | puerto escondido
# Processing Record 2 of Set 16 | tual
# Processing Record 3 of Set 16 | ternate
# Processing Record 4 of Set 16 | zhangjiakou
# Processing Record 5 of Set 16 | balakovo
# Processing Record 6 of Set 16 | catamarca
# Processing Record 7 of Set 16 | tromso
# Processing Record 8 of Set 16 | raub
# Processing Record 9 of Set 16 | comodoro rivadavia
# Processing Record 10 of Set 16 | gardner
# Processing Record 11 of Set 16 | aybak
# City not found. Skipping...
# Processing Record 12 of Set 16 | halalo
# City not found. Skipping...
# Processing Record 13 of Set 16 | beoumi
# Processing Record 14 of Set 16 | inuvik
# Processing Record 15 of Set 16 | padang
# Processing Record 16 of Set 16 | juba
# Processing Record 17 of Set 16 | itoman
# Processing Record 18 of Set 16 | sibut
# Processing Record 19 of Set 16 | aketi
# Processing Record 20 of Set 16 | zhigansk
# Processing Record 21 of Set 16 | greenville
# Processing Record 22 of Set 16 | turbat
# Processing Record 23 of Set 16 | riyadh
# Processing Record 24 of Set 16 | menongue
# Processing Record 25 of Set 16 | mattru
# Processing Record 26 of Set 16 | manjacaze
# Processing Record 27 of Set 16 | ko samui
# Processing Record 28 of Set 16 | visakhapatnam
# Processing Record 29 of Set 16 | vila
# Processing Record 30 of Set 16 | fortuna
# Processing Record 31 of Set 16 | uige
# Processing Record 32 of Set 16 | sahrak
# City not found. Skipping...
# Processing Record 33 of Set 16 | hovd
# Processing Record 34 of Set 16 | verkh-usugli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Converting the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df["Lat"] = city_data_df["Lat"].map("{:.2f}".format)
city_data_df["Lng"] = city_data_df["Lng"].map("{:.2f}".format)
city_data_df.head(10)
# Out:
#                 City Country     Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0          Busselton      AU  -33.65   115.33     60.55        68          98
# 1         Butaritari      KI    3.07   172.79     80.64        82         100
# 2            Rikitea      PF  -23.12  -134.97     69.69        78         100
# 3  Starokostyantyniv      UA   49.76    27.20     64.60        58          19
# 4            Ushuaia      AR  -54.80   -68.30     35.26        51          20
# 5              Adrar      MR   20.50   -10.07     89.78        22           4
# 6     Saint-Augustin      CA   51.23   -58.65     53.35        95         100
# 7          Mount Isa      AU  -20.73   139.50     74.97        25           0
# 8        Yellowknife      CA   62.46  -114.35     59.56        77          75
# 9         Coahuayana      MX   18.73  -103.68     77.47        80         100
#
#    Wind Speed Current Description
# 0        5.30     overcast clouds
# 1       16.33       moderate rain
# 2        9.95          light rain
# 3        4.65          few clouds
# 4       12.66          few clouds
# 5        3.22           clear sky
# 6        4.41     overcast clouds
# 7        6.91          light rain
# 8        6.91       broken clouds
# 9        3.76     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
